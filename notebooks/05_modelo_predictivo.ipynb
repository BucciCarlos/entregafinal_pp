# %% [markdown]
# # 05. Modelo Predictivo
#
# Este notebook aborda la preparación final de los datos para modelado, división del dataset, selección de algoritmos de Machine Learning, optimización de hiperparámetros y evaluación de métricas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
